# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N_list = [1000, 5000, 10000]
g_list = np.arange(0.1, 5.1, 0.1)
phi = np.tanh
T = 10000
Tinit = 1000
sigma = 1.
nums = 10

# %%
coef = np.load("data/coef_cauchy.npy")

# %%
markers =["o", "x", "D"]
colors = ["darkgray", "dimgray", "black"]

for idN, N in enumerate(N_list):
    plt.errorbar(g_list, np.mean(coef[idN], axis=1), np.std(coef[idN], axis=1), marker=markers[idN], color=colors[idN], capsize=5, label=f"N={N}")
plt.xticks([0.1, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5], size=15)
plt.yticks(size=15)
plt.xlabel(r"$\gamma$", size=25)
plt.ylabel(r"$\sqrt{ \left\langle \rho_{ij}^2 \right\rangle_{\rm pairwise} }$", size=20)
#plt.title(f"Cauchy: N={N}, sigma_s={sigma}, sigma_n=0")
plt.legend(fontsize=15)
plt.grid(linewidth=0.2)
plt.show()
